# %% [markdown]
# <a href="https://colab.research.google.com/github/soni113/python/blob/main/face_mask_detector.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img[0]
# Out:
# array([[21, 32, 29],
#        [19, 30, 27],
#        [18, 29, 26],
#        ...,
#        [18, 40, 35],
#        [16, 38, 33],
#        [16, 38, 33]], dtype=uint8)

# %%
img
# Out:
# array([[[ 21,  32,  29],
#         [ 19,  30,  27],
#         [ 18,  29,  26],
#         ...,
#         [ 18,  40,  35],
#         [ 16,  38,  33],
#         [ 16,  38,  33]],
#
#        [[ 19,  30,  27],
#         [ 18,  29,  26],
#         [ 17,  28,  25],
#         ...,
#         [ 19,  41,  36],
#         [ 18,  40,  35],
#         [ 17,  39,  34]],
#
#        [[ 19,  27,  26],
#         [ 18,  26,  25],
#         [ 18,  26,  25],
#         ...,
#         [ 25,  45,  40],
#         [ 24,  44,  39],
#         [ 23,  43,  38]],
#
#        ...,
#
#        [[122, 179, 188],
#         [122, 179, 188],
#         [122, 179, 188],
#         ...,
#         [101, 166, 167],
#         [ 97, 162, 163],
#         [ 96, 161, 162]],
#
#        [[121, 178, 187],
#         [121, 178, 187],
#         [121, 178, 187],
#         ...,
#         [102, 167, 168],
#         [ 94, 159, 160],
#         [ 93, 158, 159]],
#
#        [[121, 178, 187],
#         [122, 179, 188],
#         [122, 179, 188],
# ...

# %%
img = cv2.imread('/MS-Dhoni-and-Virat-Kohli.jpg')
img.shape
# Out:
# (605, 806, 3)

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(img)

# %%
img = cv2.imread('/MS-Dhoni-and-Virat-Kohli.jpg')
gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

fig, ax = plt.subplots(ncols=2)

ax[0].imshow(img[..., ::-1])  # BGR to RGB
ax[0].set_title('Original image')

ax[1].imshow(gray_img, cmap=plt.cm.gray)
ax[1].set_title('Grayscale image')

plt.show()

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-2cba98db-d08b-41ea-98a0-1f038b07d1c7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2cba98db-d08b-41ea-98a0-1f038b07d1c7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving data.xml to data.xml

# %%
haar_data = cv2.CascadeClassifier('data.xml')

# %%
haar_data.detectMultiScale(img)
# Out:
# array([[214,  64, 142, 142],
#        [436,  75, 138, 138]], dtype=int32)

# %%
capture = haar_data(gray,1.1,4)
